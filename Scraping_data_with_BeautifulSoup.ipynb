# %% [markdown]
# ### Importing Libraries

# %%
import requests
from bs4 import BeautifulSoup
import re 
import pandas as pd

# %% [markdown]
# ### Collecting Data

# %%
#  checking whether the web page at the given URL is accessible and whether the request is successful
r = requests.get('https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=3')
print(r.status_code)
# Out:
# 200

# %%
def get_all_pages():
    
    urls = []
    page_number = 1
    
    for i in range(107):
        i = f"https://www.barreaudenice.com/annuaire/avocats/?fwp_paged={page_number}"
        page_number += 1
        urls.append(i)
    return urls

# %%
get_all_pages()
# Out:
# ['https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=1',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=2',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=3',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=4',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=5',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=6',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=7',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=8',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=9',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=10',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=11',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=12',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=13',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=14',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=15',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=16',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=17',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=18',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=19',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=20',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=21',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=22',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=23',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=24',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=25',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=26',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=27',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=28',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=29',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=30',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=31',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=32',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=33',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=34',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=35',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=36',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=37',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=38',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=39',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=40',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=41',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=42',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=43',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=44',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=45',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=46',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=47',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=48',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=49',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=50',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=51',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=52',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=53',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=54',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=55',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=56',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=57',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=58',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=59',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=60',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=61',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=62',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=63',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=64',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=65',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=66',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=67',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=68',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=69',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=70',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=71',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=72',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=73',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=74',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=75',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=76',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=77',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=78',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=79',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=80',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=81',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=82',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=83',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=84',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=85',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=86',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=87',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=88',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=89',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=90',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=91',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=92',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=93',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=94',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=95',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=96',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=97',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=98',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=99',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=100',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=101',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=102',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=103',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=104',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=105',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=106',
#  'https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=107']

# %%
def parse_attorney():
    r = requests.get("https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=1")
    soup = BeautifulSoup(r.content, 'html.parser')
    
    print(soup)

# %%
parse_attorney()
# Out:
#  <!DOCTYPE html>
#
# <html lang="fr-FR">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="telephone=no" name="format-detection"/>
# <meta content="zzvBgaNkcs5mmEWQMp_LgDNDm6CyPikAt4kAXZY10-8" name="google-site-verification">
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>
# 			Barreau de Nice |
# 			Ordre des Avocats du Barreau de Nice		</title>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <!-- This site is optimized with the Yoast SEO plugin v20.3 - https://yoast.com/wordpress/plugins/seo/ -->
# <link href="https://www.barreaudenice.com/annuaire/avocats/" rel="canonical">
# <meta content="fr_FR" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Avocats - Barreau de Nice" property="og:title"/>
# <meta content="https://www.barreaudenice.com/annuaire/avocats/" property="og:url"/>
# <meta content="Barreau de Nice" property="og:site_name"/>
# <meta content="2021-11-29T14:29:58+00:00" property="article:modified_time"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://www.barreaudenice.com/annuaire/avocats/","url":"https://www.barreaudenice.com/annuaire/avocats/","name":"Avocats - Barreau de Nice","isPartOf":{"@id":"https://www.barreaudenice.com/#website"},"datePublished":"2017-01-13T12:18:54+00:00","dateModified":"2021-11-29T14:29:58+00:00","breadcrumb":{"@id":"https://www.barreaudenice.com/annuaire/avocats/#breadcrumb"},"inLanguage":"fr-FR","potentialAction":[{"@type":"ReadAction","target":["https://www.barreaudenice.com/annuaire/avocats/"]}]},{"@type":"BreadcrumbList","@id":"https://www.barreaudenice.com/annuaire/avocats/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Accueil","item":"https://www.barreaudenice.com/"},{"@type":"ListItem","position":2,"name":"Annuaires","item":"https://www.barreaudenice.com/annuaire/"},{"@type":"ListItem","position":3,"name":"Avocats"}]},{"@type":"WebSite","@id":"https://www.barreaudenice.com/#website","url":"https://www.barreaudenice.com/","name":"Barreau de Nice","description":"Ordre des Avocats du Barreau de Nice","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.barreaudenice.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"fr-FR"}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//maps.googleapis.com" rel="dns-prefetch">
# <link href="//code.jquery.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.barreaudenice.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=6.1.1"}};
# /*! This file is auto-generated */
# !function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode,e=(p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0),i.toDataURL());return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(p&&p.fillText)switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([129777,127995,8205,129778,127999],[129777,127995,8203,129778,127999])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(e=t.source||{}).concatemoji?c(e.concatemoji):e.wpemoji&&e.twemoji&&(c(e.twemoji),c(e.wpemoji)))}(window,document,window._wpemojiSettings);
# </script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 0.07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://www.barreaudenice.com/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.7.4" id="contact-form-7-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/styles/vendor/foundation.css?ver=6.1.1" id="foundation-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/styles/vendor/jquery.bxslider.css?ver=6.1.1" id="bxslider-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/styles/vendor/uniform.css?ver=6.1.1" id="uniform-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/styles/vendor/jquery.selectBoxIt.css?ver=6.1.1" id="selectBoxIt-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/styles/vendor/colorbox.css?ver=6.1.1" id="colorbox-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/styles/local/styles.css?ver=6.1.1" id="style-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jquery-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/vendor/jquery.min.js?ver=2.1.0" type="text/javascript"></script>
# <script id="foundation-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/vendor/foundation.min.js?ver=1.0.0" type="text/javascript"></script>
# <script id="jquery-ui-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/vendor/jquery-ui.js?ver=1.0.0" type="text/javascript"></script>
# <script id="jquery.sticky-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/vendor/jquery.sticky.js?ver=1.0.0" type="text/javascript"></script>
# <script id="jquery.bxslider-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/vendor/jquery.bxslider.min.js?ver=1.0.0" type="text/javascript"></script>
# <script id="jquery.uniform-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/vendor/jquery.uniform.js?ver=1.0.0" type="text/javascript"></script>
# <script id="jquery.selectBoxIt-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/vendor/jquery.selectBoxIt.js?ver=1.0.0" type="text/javascript"></script>
# <script id="jquery.colorbox-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/vendor/jquery.colorbox-min.js?ver=1.6.4" type="text/javascript"></script>
# <script id="google-maps-api-js" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyCsd3KYHyI1Zc6Mj-FLp4kK4D89AURzu1U&amp;ver=1.0.0" type="text/javascript"></script>
# <script id="jqueryui-js" src="//code.jquery.com/ui/1.12.1/jquery-ui.js?ver=1.0.0" type="text/javascript"></script>
# <script id="scripts-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var ajax_login_object = {"ajaxurl":"https:\/\/www.barreaudenice.com\/wp-admin\/admin-ajax.php","redirecturl":"https:\/\/www.barreaudenice.com\/espace-avocats\/documentation\/","loadingmessage":"Envoi d'informations aux utilisateurs, veuillez patienter..."};
# /* ]]> */
# </script>
# <script id="scripts-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/local/jquery.app.js?ver=1.0.0" type="text/javascript"></script>
# <script id="script-popup-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/vendor/popup.js?ver=1.0.1" type="text/javascript"></script>
# <script id="jqueryvalidate-js" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/scripts/local/jquery.validate.js?ver=1.0.0" type="text/javascript"></script>
# <link href="https://www.barreaudenice.com/wp-json/" rel="https://api.w.org/"/><link href="https://www.barreaudenice.com/wp-json/wp/v2/pages/34" rel="alternate" type="application/json"/><meta content="WordPress 6.1.1" name="generator"/>
# <link href="https://www.barreaudenice.com/?p=34" rel="shortlink"/>
# <link href="https://www.barreaudenice.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.barreaudenice.com%2Fannuaire%2Favocats%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://www.barreaudenice.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.barreaudenice.com%2Fannuaire%2Favocats%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <link href="https://www.barreaudenice.com/telechargements/2017/01/cropped-logo-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://www.barreaudenice.com/telechargements/2017/01/cropped-logo-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://www.barreaudenice.com/telechargements/2017/01/cropped-logo-180x180.png" rel="apple-touch-icon"/>
# <meta content="https://www.barreaudenice.com/telechargements/2017/01/cropped-logo-270x270.png" name="msapplication-TileImage"/>
# </link></link></meta></meta></head>
# <body class="page-template page-template-templates page-template-annuaire page-template-templatesannuaire-php page page-id-34 page-child parent-pageid-64014">
# <div class="site" id="page">
# <header class="header">
# <div class="row">
# <div class="column small-12">
# <div class="logo">
# <a href="https://www.barreaudenice.com/" title="Lien vers :https://www.barreaudenice.com/">
# <img alt="" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/media/images/logo.jpg" title=""/>
# </a>
# </div>
# <!-- .site-branding -->
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <div class="menu-menu-sticky-container"><ul class="dropdown menu" id="primary-menu"><li class="page-noncliquable menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-3093" id="menu-item-3093"><a href="https://www.barreaudenice.com/barreaudenice/">Barreau de Nice</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-85" id="menu-item-85"><a href="https://www.barreaudenice.com/barreaudenice/presentation/">Présentation</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-84" id="menu-item-84"><a href="https://www.barreaudenice.com/barreaudenice/monsieur-le-batonnier-madame-le-vice-batonnier-et-le-conseil-de-lordre/">Monsieur le Bâtonnier, Madame le Vice-Bâtonnier et le Conseil de l’Ordre</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-68" id="menu-item-68"><a href="https://www.barreaudenice.com/centre-justice-amiable/">Centre Justice Amiable</a></li>
# <li class="page-noncliquable menu-item menu-item-type-custom menu-item-object-custom current-menu-ancestor current-menu-parent menu-item-has-children menu-item-64005" id="menu-item-64005"><a href="#">Annuaires</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-34 current_page_item menu-item-64010" id="menu-item-64010"><a aria-current="page" href="https://www.barreaudenice.com/annuaire/avocats/">Avocats</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-64009" id="menu-item-64009"><a href="https://www.barreaudenice.com/annuaire/bureaux-secondaires/">Bureaux secondaires</a></li>
# </ul>
# </li>
# <li class="page-noncliquable menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-3090" id="menu-item-3090"><a href="https://www.barreaudenice.com/contacts-infos-pratiques/">Contacts &amp; infos pratiques</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-87" id="menu-item-87"><a href="https://www.barreaudenice.com/contacts-infos-pratiques/contact/">Contact</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-86" id="menu-item-86"><a href="https://www.barreaudenice.com/contacts-infos-pratiques/renseignements-pratiques/">Renseignements pratiques</a></li>
# </ul>
# </li>
# </ul></div> <div class="menu-connexion-utilisateur-container"><ul class="menu" id="menu-6"><li class="login-popup menu-item menu-item-type-custom menu-item-object-custom menu-item-547" id="menu-item-547"><a href="#login-form">Espace avocats</a></li>
# </ul></div> </nav>
# <!-- #site-navigation -->
# <div class="search-header">
# <span class="input-group-addon"><i class="icon-loop"></i></span>
# <form action="https://www.barreaudenice.com" class="search-form form-inline" id="commentForm" method="get" role="search">
# <div class="form-group">
# <label class="sr-only" for="s">Recherche :</label>
# <div class="input-group">
# <input class="form-control" id="search-form" name="s" placeholder="Recherche..." title="Recherche" type="search" value=""/>
# </div>
# </div>
# <button class="button primary" type="submit">OK</button>
# </form>
# </div>
# <div class="burger-menu hide-for-large-only"><span></span></div>
# </div>
# </div>
# </header>
# <!-- #masthead -->
# <div class="site-content" id="content">
# <div class="sidebar">
# <ul>
# <li><a href="https://www.barreaudenice.com/annuaire/avocats" title="Lien vers : https://www.barreaudenice.com/annuaire/avocats">Trouver <br/> un avocat</a></li>
# <li><a href="https://www.barreaudenice.com/annuaire/bureaux-secondaires" title="Lien vers : https://www.barreaudenice.com/annuaire/bureaux-secondaires">Trouver un <br/> bureau secondaire</a></li>
# <li><a href="https://www.barreaudenice.com/aide-juridictionnelle" title="Lien vers : https://www.barreaudenice.com/aide-juridictionnelle">Aide <br/> Juridictionnelle</a></li>
# <li><a href="https://www.barreaudenice.com/presse" title="Lien vers : https://www.barreaudenice.com/presse">Attentat du 14 juillet</a></li>
# <li><a href="https://www.barreaudenice.com/ukraine" title="Lien vers : https://www.barreaudenice.com/ukraine">Ukraine</a></li>
# <li><a href="https://www.barreaudenice.com/#actualites">Actualités</a></li>
# </ul>
# </div>
# <div class="diaporama">
# <ul class="bxslider">
# <li class="image">
# <img alt="slide01" src="https://www.barreaudenice.com/telechargements/2017/01/slide01.jpg"/>
# </li>
# </ul>
# <div class="row bloc-contact">
# <div class="column small-8 medium-5 large-4">
# <strong class="titre-bloc-contact">ORDRE DES AVOCATS  AU BARREAU DE NICE</strong>
# <address>
# <p>Place du Palais</p>
# <p>Palais de Justice</p>
# <p>06300 NICE</p>
# <p>Tél.: 04 93 85 12 03</p>
# <p>Fax : 04 93 92 34 56</p>
# </address>
# <a class="button large" href="https://www.barreaudenice.com/contacts-infos-pratiques/contact/" title="Lien vers :https://www.barreaudenice.com/contacts-infos-pratiques/contact/">
# <i class="icon-right"></i>Prendre contact                </a>
# </div>
# </div>
# </div><div class="scrolto"></div>
# <div class="bloc_accueil has-breadcrumbs">
# <div class="row">
# <div class="column small-12">
# <nav aria-label="Vous êtes ici : " role="navigation"><ul class="breadcrumbs breadcrumbs" id="breadcrumbs"><li class="item-home"><a class="bread-link bread-home" href="https://www.barreaudenice.com" title="Accueil">Accueil</a></li><li class="item-parent item-parent-64014">Annuaires</li><li class="item-current item-34">Avocats</li></ul></nav> </div>
# </div>
# <div class="row">
# <div class="column small-12 medium-12 large-8 large-push-2">
# <div class="content">
# </div>
# </div>
# </div>
# </div>
# <div class="block-annuaires" id="annuaires">
# <h2 class="text-center">Avocats</h2>
# <div class="block-search">
# <div class="text-center">
# <div class="text-left inline-block">
# <div class="facetwp-facet facetwp-facet-nom facetwp-type-autocomplete" data-name="nom" data-type="autocomplete"></div> <div class="facetwp-facet facetwp-facet-specialites facetwp-type-dropdown" data-name="specialites" data-type="dropdown"></div> <div class="facetwp-facet facetwp-facet-ville facetwp-type-dropdown" data-name="ville" data-type="dropdown"></div> <div class="input-wrapper">
# <button class="hollow button primary" id="search-filter" type="button">
#                         Rechercher                    </button>
# <button class="hollow button primary" onclick="FWP.reset()">
#                         Réinitialiser                    </button>
# </div>
# </div>
# </div>
# </div>
# <div class="block-list-annuaires">
# <div class="facetwp-template" data-name="annuaire"> <div class="row">
# <div class="column small-12">
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2018/03/ABASSIT-Florian018.jpg" title="ABASSIT Florian018">
# </img></div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABASSIT Florian                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									16/01/2018								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								31, avenue Jean Médecin                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 06 50 86 91 62							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 701							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:avocat@florian-abassit.com">
#                                     avocat@florian-abassit.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABASSIT Florian%0A%0APrestation de serment : 16/01/2018%0A%0AN° de Case : 701%0A%0AEmail : avocat@florian-abassit.com%0A%0AAdresse : 31  avenue Jean Médecin 06000 Nice%0A%0ATéléphone : 06 50 86 91 62%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ABBATIA.jpg" title="ABBATIA"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABBATI Anaïs                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									06/01/2012								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								13, rue Alphonse Karr<br/>
# Le Louvre                                                                    06004                                                                                                							</span>
# <span class="telephone">
# 								T . 04 97 03 11 50							</span>
# <span class="fax">
# 								F . 04 97 03 11 59							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 42							</span>
# <span class="intitule-droit">
# 								Droit fiscal et droit douanier                            </span>
# <span class="email">
#                                 Email :                                 <a href="mailto:anais.abbati@alister-avocats.eu">
#                                     anais.abbati@alister-avocats.eu                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABBATI Anaïs%0A%0APrestation de serment : 06/01/2012%0A%0AN° de Case : 42%0A%0ASpécialité(s) : Droit fiscal et droit douanier%0A%0AEmail : anais.abbati@alister-avocats.eu%0A%0AAdresse : 13  rue Alphonse Karr
# Le Louvre 06004 %0A%0ATéléphone : 04 97 03 11 50%0A%0AFax : 04 97 03 11 59%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/profile-default.png"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABDALLAOUI Myriam                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2022								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								8 rue Alfred Mortier                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 80 63 01							</span>
# <span class="fax">
# 								F . 04 93 62 30 11							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 299							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:myriam-abdallaoui@hotmail.com">
#                                     myriam-abdallaoui@hotmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABDALLAOUI Myriam%0A%0APrestation de serment : 07/01/2022%0A%0AN° de Case : 299%0A%0AEmail : myriam-abdallaoui@hotmail.com%0A%0AAdresse : 8 rue Alfred Mortier 06000 Nice%0A%0ATéléphone : 04 93 80 63 01%0A%0AFax : 04 93 62 30 11%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/profile-default.png"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABDALLAOUI Myriam                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2022								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								8 rue Alfred Mortier                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 80 63 01							</span>
# <span class="fax">
# 								F . 04 93 62 30 11							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 299							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:myriam-abdallaoui@hotmail.com">
#                                     myriam-abdallaoui@hotmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABDALLAOUI Myriam%0A%0APrestation de serment : 07/01/2022%0A%0AN° de Case : 299%0A%0AEmail : myriam-abdallaoui@hotmail.com%0A%0AAdresse : 8 rue Alfred Mortier 06000 Nice%0A%0ATéléphone : 04 93 80 63 01%0A%0AFax : 04 93 62 30 11%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2022/02/Abdoul-ABDOULAYE.jpg" title="Abdoul ABDOULAYE">
# </img></div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABDOULAYE MOUSSA Abdoul Wahab                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2022								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								16, boulevard Raimbaldi                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 06 51 83 90 86							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 770							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:abdoul.abdoulayemoussa@gmail.com">
#                                     abdoul.abdoulayemoussa@gmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABDOULAYE MOUSSA Abdoul Wahab%0A%0APrestation de serment : 07/01/2022%0A%0AN° de Case : 770%0A%0AEmail : abdoul.abdoulayemoussa@gmail.com%0A%0AAdresse : 16  boulevard Raimbaldi  06000 Nice%0A%0ATéléphone : 06 51 83 90 86%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ABECASSIS.jpg" title="ABECASSIS">
# </img></div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABECASSIS Charles                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									08/01/1988								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								1, Place Magenta<br/>
#                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 88 30 17							</span>
# <span class="fax">
# 								F . 04 93 87 61 57							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 270							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:ch.abk6@wanadoo.fr">
#                                     ch.abk6@wanadoo.fr                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABECASSIS Charles%0A%0APrestation de serment : 08/01/1988%0A%0AN° de Case : 270%0A%0AEmail : ch.abk6@wanadoo.fr%0A%0AAdresse : 1  Place Magenta
#  06000 Nice%0A%0ATéléphone : 04 93 88 30 17%0A%0AFax : 04 93 87 61 57%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ABID.jpg" title="ABID"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABID Samih                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2002								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								35, rue Gioffredo<br/>
#                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 87 71 06							</span>
# <span class="fax">
# 								F . 04 93 01 22 45							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 493							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:contact@abid-avocats.com">
#                                     contact@abid-avocats.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABID Samih%0A%0APrestation de serment : 07/01/2002%0A%0AN° de Case : 493%0A%0AEmail : contact@abid-avocats.com%0A%0AAdresse : 35  rue Gioffredo
#  06000 Nice%0A%0ATéléphone : 04 93 87 71 06%0A%0AFax : 04 93 01 22 45%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2019/01/ABIER-ROUGERON-Stéphanie019.jpg" title="ABIER-ROUGERON Stéphanie019"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABIER-ROUGERON Stéphanie                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									15/01/2019								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								22, rue Gounod                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 06 30 12 89 76							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 563							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:rougeronavocat@gmail.com">
#                                     rougeronavocat@gmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABIER-ROUGERON Stéphanie%0A%0APrestation de serment : 15/01/2019%0A%0AN° de Case : 563%0A%0AEmail : rougeronavocat@gmail.com%0A%0AAdresse : 22  rue Gounod 06000 Nice%0A%0ATéléphone : 06 30 12 89 76%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/profile-default.png"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABOU EL HAJA Aziza                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/03/2016								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								1 Boulevard Général Delfino                                                                    06300                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 85 70 23							</span>
# <span class="fax">
# 								F . 09 70 10 61 66							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 715							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:aeh.avocat@gmail.com">
#                                     aeh.avocat@gmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABOU EL HAJA Aziza%0A%0APrestation de serment : 07/03/2016%0A%0AN° de Case : 715%0A%0AEmail : aeh.avocat@gmail.com%0A%0AAdresse : 1 Boulevard Général Delfino 06300 Nice%0A%0ATéléphone : 04 93 85 70 23%0A%0AFax : 09 70 10 61 66%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ABRAN.jpg" title="ABRAN">
# </img></div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABRAN Grégory                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									14/01/2009								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								40, bd Victor Hugo<br/>
#                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 06 15 33 07 26							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 69							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:abran.gregory@gmail.com">
#                                     abran.gregory@gmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABRAN Grégory%0A%0APrestation de serment : 14/01/2009%0A%0AN° de Case : 69%0A%0AEmail : abran.gregory@gmail.com%0A%0AAdresse : 40  bd Victor Hugo
#  06000 Nice%0A%0ATéléphone : 06 15 33 07 26%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ACHACHE.jpg" title="ACHACHE"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ACHACHE Hélène                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									24/01/1989								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								1, rue Alberti<br/>
#                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 82 14 14							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 416							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:hhlnhh@aol.com">
#                                     hhlnhh@aol.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ACHACHE Hélène%0A%0APrestation de serment : 24/01/1989%0A%0AN° de Case : 416%0A%0AEmail : hhlnhh@aol.com%0A%0AAdresse : 1  rue Alberti
#  06000 Nice%0A%0ATéléphone : 04 93 82 14 14%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ADADE.jpg" title="ADADE"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ADAD Eric                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2002								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								57, Promenade des Anglais                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 92 10 03 47							</span>
# <span class="fax">
# 								F . 04 92 10 05 29							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 286							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:eadad@talliance-avocats.fr">
#                                     eadad@talliance-avocats.fr                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ADAD Eric%0A%0APrestation de serment : 07/01/2002%0A%0AN° de Case : 286%0A%0AEmail : eadad@talliance-avocats.fr%0A%0AAdresse : 57  Promenade des Anglais 06000 Nice%0A%0ATéléphone : 04 92 10 03 47%0A%0AFax : 04 92 10 05 29%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>
# </div>
# </div>
# </div> <div class="pagination-wrapper">
# <div class="row">
# <div class="column small-12">
# <div class="facetwp-pager"></div> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hide" id="login-form">
# <img alt="Barreau de nice" src="https://www.barreaudenice.com/wp-content/themes/barreaudenice/styles/assets/media/images/logo.jpg" title="Barreau de nice"/>
# <form action="login" id="loginform" method="post">
# <p class="status"></p>
# <p class="login-username">
# <label for="user_login">Nom d’utilisateur ou adresse e-mail</label>
# <input aria-invalid="false" aria-required="true" class="input valid" id="user_login" name="log" size="20" type="text" value=""/>
# </p>
# <p class="login-password">
# <label for="user_pass">Mot de passe</label>
# <input aria-invalid="false" aria-required="true" class="input valid" id="user_pass" name="pwd" size="20" type="password" value=""/>
# </p>
# <!-- <p class="login-remember"><label><input name="rememberme" type="checkbox" id="rememberme" value="true"> Se souvenir de moi</label></p> -->
# <p class="astuce"><span>Astuce :</span> il vous faut accepter l'installation du cookies et enregistrer votre mot de passe depuis votre navigateur web pour vous permettre de vous connecter plus rapidement les prochaines fois</p>
# <p class="login-submit">
# <input class="button button-primary" id="wp-submit" name="wp-submit" type="submit" value="Se connecter"/>
# </p>
# <input class="submit_button" name="submit" type="submit" value="Login"/>
# <input id="security" name="security" type="hidden" value="478ace2100"><input name="_wp_http_referer" type="hidden" value="/annuaire/avocats/?fwp_paged=1"> </input></input></form>
# </div>
# </div>
# <!-- #content -->
# <footer class="site-footer">
# <div class="footer-area">
# <div class="row">
# <div class="column small-12 medium-12 large-3 apropos">
# <div class="bloc-theme-cat widget-bloc"><h3>A propos<br/> du Barreau de nice</h3>Les avocats au Barreau de Nice sont plus de 1000 en 2017.</div><div class="widgetizedArea">
# <p></p>
# </div><div class="widgetizedArea">
# <figure class="wp-block-image is-resized"><img alt="" class="wp-image-78212" decoding="async" height="167" loading="lazy" sizes="(max-width: 114px) 100vw, 114px" src="https://www.barreaudenice.com/telechargements/2023/01/Logo-fond-blanc-.png" srcset="https://www.barreaudenice.com/telechargements/2023/01/Logo-fond-blanc-.png 546w, https://www.barreaudenice.com/telechargements/2023/01/Logo-fond-blanc--206x300.png 206w" width="114"/></figure>
# </div><div class="widgetizedArea">
# <p></p>
# </div><div class="widgetizedArea">
# <p></p>
# </div><div class="widgetizedArea">
# <p></p>
# </div><div class="widgetizedArea">
# <figure class="wp-block-image size-full is-resized"><img alt="" class="wp-image-78215" decoding="async" height="84" loading="lazy" sizes="(max-width: 113px) 100vw, 113px" src="https://www.barreaudenice.com/telechargements/2023/01/Kerialis-site-.png" srcset="https://www.barreaudenice.com/telechargements/2023/01/Kerialis-site-.png 383w, https://www.barreaudenice.com/telechargements/2023/01/Kerialis-site--300x221.png 300w" width="113"/></figure>
# </div> </div>
# <div class="column small-12 medium-12 large-3 col2">
# <div class="bloc-theme-cat widget-bloc"><h3>Barreau de nice</h3><div class="menu-barreau-de-nice-container"><ul class="footer-menu-listing" id="menu-barreau-de-nice"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-111" id="menu-item-111"><a href="https://www.barreaudenice.com/barreaudenice/presentation/">Présentation</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-112" id="menu-item-112"><a href="https://www.barreaudenice.com/barreaudenice/monsieur-le-batonnier-madame-le-vice-batonnier-et-le-conseil-de-lordre/">Monsieur le Bâtonnier, Madame le Vice-Bâtonnier et le Conseil de l’Ordre</a></li>
# </ul></div></div><div class="bloc-theme-cat widget-bloc"><h3>Annuaires</h3><div class="menu-annuaires-container"><ul class="footer-menu-listing" id="menu-annuaires"><li class="titre-niveau1 menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-34 current_page_item menu-item-202" id="menu-item-202"><a aria-current="page" href="https://www.barreaudenice.com/annuaire/avocats/">Avocats</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-64013" id="menu-item-64013"><a href="https://www.barreaudenice.com/annuaire/bureaux-secondaires/">Bureaux secondaires</a></li>
# </ul></div></div><div class="bloc-theme-cat widget-bloc"><div class="menu-centre-justice-amiable-container"><ul class="footer-menu-listing" id="menu-centre-justice-amiable"><li class="titre-niveau1 menu-item menu-item-type-post_type menu-item-object-page menu-item-7146" id="menu-item-7146"><a href="https://www.barreaudenice.com/centre-justice-amiable/">Centre Justice Amiable</a></li>
# </ul></div></div> </div>
# <div class="column small-12 medium-12 large-3 col3">
# <div class="bloc-theme-cat widget-bloc"><h3>Contact &amp; infos pratiques</h3><div class="menu-contact-et-infos-pratiques-container"><ul class="footer-menu-listing" id="menu-contact-et-infos-pratiques"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-117" id="menu-item-117"><a href="https://www.barreaudenice.com/contacts-infos-pratiques/contact/">Contact</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7251" id="menu-item-7251"><a href="https://www.barreaudenice.com/contacts-infos-pratiques/renseignements-pratiques/">Renseignements pratiques</a></li>
# </ul></div></div> <div class="menu-espace-avocats-mode-deconnecte-container"><ul class="menu" id="menu-178"><li class="login-popup titre-niveau1 menu-item menu-item-type-custom menu-item-object-custom menu-item-7248" id="menu-item-7248"><a href="#login-form">Espace avocats</a></li>
# </ul></div> </div>
# <div class="column small-12 medium-12 large-3 col4">
# <div class="bloc-theme-cat widget-bloc"><h3>Liens utiles</h3><div class="menu-liens-utiles-container"><ul class="footer-menu-listing" id="menu-liens-utiles"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27850" id="menu-item-27850"><a href="http://avocats-droit-famille.fr/">ADF Association des Avocats praticiens en Droit de la Famille</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-139" id="menu-item-139"><a href="http://cnb.avocat.fr" rel="noopener" target="_blank">Conseil National des Barreaux</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-392" id="menu-item-392"><a href="http://www.eda-sudest.fr/" rel="noopener" target="_blank">Centre de formation des Barreaux du Sud-Est (CFBSE)</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-393" id="menu-item-393"><a href="http://www.aaf-06.com" rel="noopener" target="_blank">Association des avocats fiscalistes</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-394" id="menu-item-394"><a href="http://www.avocats-droit-affaires.com" rel="noopener" target="_blank">Association d’Avocats en Droit des Affaires</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-395" id="menu-item-395"><a href="http://www.aapds.com" rel="noopener" target="_blank">Association des Avocats Praticiens en Droit Social</a></li>
# </ul></div></div> </div>
# </div>
# </div>
# <div class="footer-plansite">
# <div class="row">
# <div class="column small-12">
# <div class="menu-menu-footer-container"><ul class="menu" id="menu-menu-footer"><li class="non-afficher menu-item menu-item-type-post_type menu-item-object-page menu-item-150" id="menu-item-150"><a href="https://www.barreaudenice.com/plan-du-site/">Plan du site</a></li>
# <li class="titre-niveau1 menu-item menu-item-type-post_type menu-item-object-page menu-item-149" id="menu-item-149"><a href="https://www.barreaudenice.com/mentions-legales/">Mentions légales</a></li>
# <li class="titre-niveau1 menu-item menu-item-type-post_type menu-item-object-page menu-item-148" id="menu-item-148"><a href="https://www.barreaudenice.com/credits/">Crédits</a></li>
# </ul></div> <span class="copyright">2022 Copyright</span>
# </div>
# </div>
# </div>
# </footer>
# <!-- #colophon -->
# <script id="swv-js" src="https://www.barreaudenice.com/wp-content/plugins/contact-form-7/includes/swv/js/index.js?ver=5.7.4" type="text/javascript"></script>
# <script id="contact-form-7-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"api":{"root":"https:\/\/www.barreaudenice.com\/wp-json\/","namespace":"contact-form-7\/v1"}};
# /* ]]> */
# </script>
# <script id="contact-form-7-js" src="https://www.barreaudenice.com/wp-content/plugins/contact-form-7/includes/js/index.js?ver=5.7.4" type="text/javascript"></script>
# <link href="https://www.barreaudenice.com/wp-content/plugins/facetwp/assets/css/front.css?ver=4.1.7" rel="stylesheet"/>
# <script src="https://www.barreaudenice.com/wp-content/plugins/facetwp/assets/js/dist/front.min.js?ver=4.1.7"></script>
# <script src="https://www.barreaudenice.com/wp-content/plugins/facetwp/assets/vendor/fComplete/fComplete.js?ver=4.1.7"></script>
# <link href="https://www.barreaudenice.com/wp-content/plugins/facetwp/assets/vendor/fComplete/fComplete.css?ver=4.1.7" rel="stylesheet"/>
# <script>
# window.FWP_JSON = {"prefix":"fwp_","no_results_text":"Aucun r\u00e9sultat trouv\u00e9","ajaxurl":"https:\/\/www.barreaudenice.com\/wp-json\/facetwp\/v1\/refresh","nonce":"c094c60a42","preload_data":{"facets":{"nom":"<div id=\"nom\"><label for=\"nom\"> Nom<\/label><input type=\"text\" class=\"facetwp-autocomplete\" value=\"\" placeholder=\"Commencer \u00e0 taper\" autocomplete=\"off\" \/><input type=\"button\" class=\"facetwp-autocomplete-update\" value=\"Aller\" \/><\/div>","specialites":"<div id=\"specialites\"><label for=\"specialites\"> Sp\u00e9cialit\u00e9<\/label><select class=\"facetwp-dropdown\"><option value=\"\">Choisir<\/option><option value=\"droit-bancaire-et-boursier\">Droit bancaire et boursier<\/option><option value=\"droit-commercial-des-affaires-et-de-la-concurrence\">Droit commercial, des affaires et de la concurrence<\/option><option value=\"droit-de-lenvironnement\">Droit de l&#039;environnement<\/option><option value=\"droit-de-la-famille-des-personnes-et-de-leur-patri\">Droit de la famille, des personnes et de leur patrimoine<\/option><option value=\"droit-de-la-sante\">Droit de la sant\u00e9<\/option><option value=\"droit-de-la-securite-sociale-et-de-la-protection-s\">Droit de la s\u00e9curit\u00e9 sociale et de la protection sociale<\/option><option value=\"droit-des-assurances\">Droit des assurances<\/option><option value=\"droit-des-garanties-des-suretes-et-des-mesures-dex\">Droit des garanties, des s\u00fbret\u00e9s et des mesures d&#039;ex\u00e9cution<\/option><option value=\"droit-des-nouvelles-technologies-linformatique-et-\">Droit des nouvelles technologies, l&#039;informatique et de la communication<\/option><option value=\"droit-des-societes\">Droit des soci\u00e9t\u00e9s<\/option><option value=\"droit-du-credit-et-de-la-consommation\">Droit du cr\u00e9dit et de la consommation<\/option><option value=\"droit-du-dommage-corporel\">Droit du dommage corporel<\/option><option value=\"droit-du-travail\">Droit du travail<\/option><option value=\"droit-fiscal-et-droit-douanier\">Droit fiscal et droit douanier<\/option><option value=\"droit-immobilier\">Droit immobilier<\/option><option value=\"droit-penal\">Droit p\u00e9nal<\/option><option value=\"droit-public\">Droit public<\/option><option value=\"procedure-dappel\">Procedure d&#039;appel<\/option><\/select><\/div>","ville":"<div id=\"ville\"><label for=\"ville\"> Ville<\/label><select class=\"facetwp-dropdown\"><option value=\"\">Choisir<\/option><option value=\"beaulieu-sur-mer\">Beaulieu sur mer<\/option><option value=\"beausoleil\">Beausoleil<\/option><option value=\"belvedere\">Belvedere<\/option><option value=\"cap-dail\">Cap d&#039;ail<\/option><option value=\"falicon\">FALICON<\/option><option value=\"menton\">Menton<\/option><option value=\"nice\">Nice<\/option><option value=\"sospel\">SOSPEL<\/option><option value=\"tende\">Tende<\/option><option value=\"tourrette-levens\">Tourrette Levens<\/option><option value=\"villefranche-sur-mer\">Villefranche sur mer<\/option><\/select><\/div>"},"template":"","settings":{"pager":{"page":1,"per_page":12,"total_rows":1282,"total_pages":107},"num_choices":{"specialites":18,"ville":11},"labels":{"nom":"Nom","specialites":"Sp\u00e9cialit\u00e9","ville":"Ville"},"nom":{"loadingText":"Loading...","minCharsText":"Enter {n} or more characters","noResultsText":"Aucun r\u00e9sultat","maxResults":10}},"pager":"<nav class=\"custom-pagination\"><ul><li><a class=\"facetwp-page active\" data-page=\"1\">1<\/a><li><li><a class=\"facetwp-page\" data-page=\"2\">2<\/a><\/li><li><a class=\"facetwp-page\" data-page=\"3\">3<\/a><\/li><li class=\"facetwp-dots\"><span class=\"dots\">\u2026<\/span><\/li><li><a class=\"facetwp-page last-page\" data-page=\"107\">107<\/a><\/li><li><a class=\"facetwp-page\" data-page=\"2\">&raquo;<\/a><\/li><\/ul><\/nav>"},"no_results":"Aucun r\u00e9sultat"};
# window.FWP_HTTP = {"get":{"fwp_paged":"1"},"uri":"annuaire\/avocats","url_vars":{"paged":"1"}};
# </script>
# </div></body>
# </html>

# %%
def parse_attorney():
    r = requests.get("https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=1")
    soup = BeautifulSoup(r.content, 'html.parser')
    
    avocats = soup.find_all('div', class_= 'callout secondary annuaire-single')
    
    print(avocats)
    print(len(avocats)) 

    
parse_attorney()
# Out:
# [<div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2018/03/ABASSIT-Florian018.jpg" title="ABASSIT Florian018">
# </img></div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABASSIT Florian                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									16/01/2018								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								31, avenue Jean Médecin                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 06 50 86 91 62							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 701							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:avocat@florian-abassit.com">
#                                     avocat@florian-abassit.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABASSIT Florian%0A%0APrestation de serment : 16/01/2018%0A%0AN° de Case : 701%0A%0AEmail : avocat@florian-abassit.com%0A%0AAdresse : 31  avenue Jean Médecin 06000 Nice%0A%0ATéléphone : 06 50 86 91 62%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ABBATIA.jpg" title="ABBATIA"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABBATI Anaïs                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									06/01/2012								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								13, rue Alphonse Karr<br/>
# Le Louvre                                                                    06004                                                                                                							</span>
# <span class="telephone">
# 								T . 04 97 03 11 50							</span>
# <span class="fax">
# 								F . 04 97 03 11 59							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 42							</span>
# <span class="intitule-droit">
# 								Droit fiscal et droit douanier                            </span>
# <span class="email">
#                                 Email :                                 <a href="mailto:anais.abbati@alister-avocats.eu">
#                                     anais.abbati@alister-avocats.eu                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABBATI Anaïs%0A%0APrestation de serment : 06/01/2012%0A%0AN° de Case : 42%0A%0ASpécialité(s) : Droit fiscal et droit douanier%0A%0AEmail : anais.abbati@alister-avocats.eu%0A%0AAdresse : 13  rue Alphonse Karr
# Le Louvre 06004 %0A%0ATéléphone : 04 97 03 11 50%0A%0AFax : 04 97 03 11 59%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/profile-default.png"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABDALLAOUI Myriam                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2022								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								8 rue Alfred Mortier                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 80 63 01							</span>
# <span class="fax">
# 								F . 04 93 62 30 11							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 299							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:myriam-abdallaoui@hotmail.com">
#                                     myriam-abdallaoui@hotmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABDALLAOUI Myriam%0A%0APrestation de serment : 07/01/2022%0A%0AN° de Case : 299%0A%0AEmail : myriam-abdallaoui@hotmail.com%0A%0AAdresse : 8 rue Alfred Mortier 06000 Nice%0A%0ATéléphone : 04 93 80 63 01%0A%0AFax : 04 93 62 30 11%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/profile-default.png"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABDALLAOUI Myriam                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2022								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								8 rue Alfred Mortier                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 80 63 01							</span>
# <span class="fax">
# 								F . 04 93 62 30 11							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 299							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:myriam-abdallaoui@hotmail.com">
#                                     myriam-abdallaoui@hotmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABDALLAOUI Myriam%0A%0APrestation de serment : 07/01/2022%0A%0AN° de Case : 299%0A%0AEmail : myriam-abdallaoui@hotmail.com%0A%0AAdresse : 8 rue Alfred Mortier 06000 Nice%0A%0ATéléphone : 04 93 80 63 01%0A%0AFax : 04 93 62 30 11%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2022/02/Abdoul-ABDOULAYE.jpg" title="Abdoul ABDOULAYE">
# </img></div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABDOULAYE MOUSSA Abdoul Wahab                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2022								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								16, boulevard Raimbaldi                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 06 51 83 90 86							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 770							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:abdoul.abdoulayemoussa@gmail.com">
#                                     abdoul.abdoulayemoussa@gmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABDOULAYE MOUSSA Abdoul Wahab%0A%0APrestation de serment : 07/01/2022%0A%0AN° de Case : 770%0A%0AEmail : abdoul.abdoulayemoussa@gmail.com%0A%0AAdresse : 16  boulevard Raimbaldi  06000 Nice%0A%0ATéléphone : 06 51 83 90 86%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ABECASSIS.jpg" title="ABECASSIS">
# </img></div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABECASSIS Charles                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									08/01/1988								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								1, Place Magenta<br/>
#                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 88 30 17							</span>
# <span class="fax">
# 								F . 04 93 87 61 57							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 270							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:ch.abk6@wanadoo.fr">
#                                     ch.abk6@wanadoo.fr                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABECASSIS Charles%0A%0APrestation de serment : 08/01/1988%0A%0AN° de Case : 270%0A%0AEmail : ch.abk6@wanadoo.fr%0A%0AAdresse : 1  Place Magenta
#  06000 Nice%0A%0ATéléphone : 04 93 88 30 17%0A%0AFax : 04 93 87 61 57%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ABID.jpg" title="ABID"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABID Samih                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2002								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								35, rue Gioffredo<br/>
#                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 87 71 06							</span>
# <span class="fax">
# 								F . 04 93 01 22 45							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 493							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:contact@abid-avocats.com">
#                                     contact@abid-avocats.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABID Samih%0A%0APrestation de serment : 07/01/2002%0A%0AN° de Case : 493%0A%0AEmail : contact@abid-avocats.com%0A%0AAdresse : 35  rue Gioffredo
#  06000 Nice%0A%0ATéléphone : 04 93 87 71 06%0A%0AFax : 04 93 01 22 45%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2019/01/ABIER-ROUGERON-Stéphanie019.jpg" title="ABIER-ROUGERON Stéphanie019"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABIER-ROUGERON Stéphanie                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									15/01/2019								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								22, rue Gounod                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 06 30 12 89 76							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 563							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:rougeronavocat@gmail.com">
#                                     rougeronavocat@gmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABIER-ROUGERON Stéphanie%0A%0APrestation de serment : 15/01/2019%0A%0AN° de Case : 563%0A%0AEmail : rougeronavocat@gmail.com%0A%0AAdresse : 22  rue Gounod 06000 Nice%0A%0ATéléphone : 06 30 12 89 76%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/profile-default.png"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABOU EL HAJA Aziza                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/03/2016								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								1 Boulevard Général Delfino                                                                    06300                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 85 70 23							</span>
# <span class="fax">
# 								F . 09 70 10 61 66							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 715							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:aeh.avocat@gmail.com">
#                                     aeh.avocat@gmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABOU EL HAJA Aziza%0A%0APrestation de serment : 07/03/2016%0A%0AN° de Case : 715%0A%0AEmail : aeh.avocat@gmail.com%0A%0AAdresse : 1 Boulevard Général Delfino 06300 Nice%0A%0ATéléphone : 04 93 85 70 23%0A%0AFax : 09 70 10 61 66%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ABRAN.jpg" title="ABRAN">
# </img></div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ABRAN Grégory                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									14/01/2009								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								40, bd Victor Hugo<br/>
#                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 06 15 33 07 26							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 69							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:abran.gregory@gmail.com">
#                                     abran.gregory@gmail.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ABRAN Grégory%0A%0APrestation de serment : 14/01/2009%0A%0AN° de Case : 69%0A%0AEmail : abran.gregory@gmail.com%0A%0AAdresse : 40  bd Victor Hugo
#  06000 Nice%0A%0ATéléphone : 06 15 33 07 26%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ACHACHE.jpg" title="ACHACHE"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ACHACHE Hélène                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									24/01/1989								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								1, rue Alberti<br/>
#                                                                     06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 93 82 14 14							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 416							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:hhlnhh@aol.com">
#                                     hhlnhh@aol.com                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ACHACHE Hélène%0A%0APrestation de serment : 24/01/1989%0A%0AN° de Case : 416%0A%0AEmail : hhlnhh@aol.com%0A%0AAdresse : 1  rue Alberti
#  06000 Nice%0A%0ATéléphone : 04 93 82 14 14%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>, <div class="callout secondary annuaire-single">
# <div class="avocat-img">
# <img src="https://www.barreaudenice.com/telechargements/2017/01/ADADE.jpg" title="ADADE"/>
# </div>
# <div class="avocat-name">
# <h3 class="nom-prenom">
#                             ADAD Eric                        </h3>
# <span class="date-serment">
# <span>
# 									Prestation de serment :								</span>
# <span class="date">
# 									07/01/2002								</span>
# </span>
# </div>
# <div class="avocat-adresse">
# <span class="adresse">
# 								57, Promenade des Anglais                                                                    06000                                                                                                                                    Nice                                							</span>
# <span class="telephone">
# 								T . 04 92 10 03 47							</span>
# <span class="fax">
# 								F . 04 92 10 05 29							</span>
# </div>
# <div class="avocat-infos">
# <span class="num-case">
# 								N° de Case : 286							</span>
# <span class="email">
#                                 Email :                                 <a href="mailto:eadad@talliance-avocats.fr">
#                                     eadad@talliance-avocats.fr                                </a>
# </span>
# </div>
# <span class="send-email">
# <a href="mailto:?body=ADAD Eric%0A%0APrestation de serment : 07/01/2002%0A%0AN° de Case : 286%0A%0AEmail : eadad@talliance-avocats.fr%0A%0AAdresse : 57  Promenade des Anglais 06000 Nice%0A%0ATéléphone : 04 92 10 03 47%0A%0AFax : 04 92 10 05 29%0A%0A">
# <i aria-haspopup="true" class="icon-send has-tip top" data-click-open="true" data-disable-hover="false" data-tooltip="" title="Astuce : vous pouvez envoyer les coordonnées des avocats par email à vous et vos amis"></i>
#                             Envoyer la fiche par Email                        </a>
# </span>
# </div>]
# 12

# %%
def parse_attorney():
    r = requests.get("https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=1")
    soup = BeautifulSoup(r.content, 'html.parser')
    
    avocats = soup.find_all('div', class_= 'callout secondary annuaire-single')
    
    for avocat in avocats :
        
        # we want to find an 'h3' element, extract the text content from it, and then strip any whitespace
        nom = avocat.find('h3').text.strip() 
        #print(nom)
        
        adresse= avocat.find('span', class_='adresse').text.strip()
        #print(adresse)

        adresse_finale = re.sub(r"\s+"," ", adresse)  #\s+ plus one space, we replace any consecutive sequences of whitespace
        #print(adresse_finale)
        
        telephone = avocat.find('span', class_= 'telephone').text.strip()
        #print(telephone)
        
        email = avocat.find('span', class_='email').a.text.strip()
        print(email)
    

    
parse_attorney()
# Out:
# avocat@florian-abassit.com
# anais.abbati@alister-avocats.eu
# myriam-abdallaoui@hotmail.com
# myriam-abdallaoui@hotmail.com
# abdoul.abdoulayemoussa@gmail.com
# ch.abk6@wanadoo.fr
# contact@abid-avocats.com
# rougeronavocat@gmail.com
# aeh.avocat@gmail.com
# abran.gregory@gmail.com
# hhlnhh@aol.com
# eadad@talliance-avocats.fr

# %%
def parse_attorney():
    r = requests.get("https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=1") 
    soup = BeautifulSoup(r.content, 'html.parser')
    
    avocats = soup.find_all('div', class_= 'callout secondary annuaire-single')
    
    for avocat in avocats :
        
        nom = avocat.find('h3').text.strip() 
        adresse= avocat.find('span', class_='adresse').text.strip()
        adresse_finale = re.sub(r"\s+"," ", adresse)  
        telephone = avocat.find('span', class_= 'telephone').text.strip()
        email = avocat.find('span', class_='email').a.text.strip()  
        
        # Saving data in a text file
        chemin = r".\annuaire_avocat.txt"
        with open(chemin, "a") as f:
        
            f.write(f"{nom}\n")
            f.write(f"{adresse_finale}\n")
            f.write(f"{telephone}\n")
            f.write(f"{email}\n\n")
    
parse_attorney()

# %%
def parse_attorney1(url):
    r = requests.get(url) 
    soup = BeautifulSoup(r.content, 'html.parser')
    
    avocats = soup.find_all('div', class_= 'callout secondary annuaire-single')
    
    for avocat in avocats :
        
        try :
            nom = avocat.find('h3').text.strip()
        except AttributeError as e:
            nom = ""
        adresse= avocat.find('span', class_='adresse').text.strip()
        try :
            adresse_finale = re.sub(r"\s+"," ", adresse) 
        except AttributeError as e:
            adresse_finale= ""
        try :    
            telephone = avocat.find('span', class_= 'telephone').text.strip()
        except AttributeError as e:
            telephone= ""
        try :    
            email = avocat.find('span', class_='email').a.text.strip()
        except AttributeError as e:
            email =""
        
        chemin = r".\annuaire_avocat.txt"
        with open(chemin, "a") as f:
        
            f.write(f"{nom}\n")
            f.write(f"{adresse_finale}\n")
            f.write(f"{telephone}\n")
            f.write(f"{email}\n\n")
    
parse_attorney()

# %%
# scraping all pages
def parse_all_attorneys():
    pages = get_all_pages()
    for page in pages:

        parse_attorney1(url=page)
        print(f"On scrap {page}") 
     
    
parse_all_attorneys()
# Out:
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=1
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=2
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=3
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=4
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=5
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=6
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=7
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=8
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=9
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=10
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=11
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=12
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=13
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=14
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=15
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=16
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=17
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=18
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=19
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=20
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=21
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=22
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=23
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=24
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=25
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=26
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=27
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=28
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=29
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=30
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=31
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=32
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=33
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=34
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=35
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=36
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=37
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=38
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=39
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=40
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=41
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=42
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=43
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=44
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=45
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=46
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=47
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=48
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=49
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=50
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=51
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=52
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=53
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=54
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=55
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=56
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=57
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=58
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=59
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=60
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=61
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=62
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=63
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=64
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=65
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=66
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=67
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=68
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=69
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=70
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=71
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=72
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=73
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=74
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=75
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=76
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=77
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=78
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=79
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=80
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=81
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=82
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=83
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=84
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=85
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=86
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=87
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=88
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=89
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=90
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=91
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=92
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=93
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=94
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=95
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=96
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=97
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=98
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=99
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=100
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=101
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=102
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=103
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=104
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=105
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=106
# On scrap https://www.barreaudenice.com/annuaire/avocats/?fwp_paged=107
